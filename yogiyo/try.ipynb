# %%
import json
import pandas as pd
import requests
from selenium.webdriver.common.by import By
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import re
from selenium.webdriver.common.keys import Keys
import time

# %%
url = "https://www.yogiyo.co.kr/api/v2/restaurants?items=60&lat=37.5033171&lng=127.02611857&order=rank&page=2&search=&serving_type=vd"

# %%
payload = {
    "items": "300",
    "lat": "37.5033171",
    "lng": "127.02611857",
    "order": "rank",
    "page": "1",
    "search":"" ,
    "serving_type": "vd",
}

# %%
headers = {
    "Accept": "application/json",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Authorization": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE3MDczNTY0MzgsImV4cCI6MTcwNzM2MzYzOCwicGxhdGZvcm0iOiJZR1kiLCJyb2xlIjoidXNlciIsInN1Yl9pZCI6Ijg0NDUzMjE5NyIsImJhc2VfdXJsIjoiaHR0cHM6Ly93d3cueW9naXlvLmNvLmtyIn0.n4yif8czFLhJbvEPe2HV6TxRFJmz0Vu68uSXBI3HlOOvtidTuC_hf1XQ_mUxXuM1SMlsEBxHGlqKVOOf5O6_aa4aBUsUggV7oN1dvFHU7bbpcpi837rlrGJIVNlG7kmHYHsftGsiUg_GjMI_lXvj7ygNE26cuBKT0NBgKuQaqNhDUVohOo9BMDyvcn_ojsQ39eN8GlcalwCIGySnIH_mZ3DPgzo-IYv8UAeLb4cqZR_894_KjaeUVDO5lQipszXfKVAhPEGZfOzgaDlt0Mem_As0sRKexgeYm4dEiyNSoxBNR9UukP4z7NPQR2bOVYUDFfChOUKxEZbWzkulevT_Lw",
    "Content-Type": "application/x-www-form-urlencoded",
    "Cookie": "optimizelyEndUserId=oeu1707217256129r0.4160384362789571; _gid=GA1.3.1286748026.1707217257; _fwb=235BZ2hbzqql3HOynLrZUjJ.1707217256848; _gcl_au=1.1.2062595015.1707217257; _fbp=fb.2.1707217257037.2107194958; _ga_6KMY7BWK8X=GS1.1.1707356497.5.0.1707356497.60.0.0; _ga=GA1.3.1795561733.1707217257; RestaurantListCookieTrigger=true; wcs_bt=s_51119d387dfa:1707356570; __cf_bm=JoCHAswANcbaQ2yqAAr2mV7evEuzd1dp6TVmfJX8oW0-1707359566-1-AcHvs5GbSJ0hL0k5+adaCOr0o6i17VC42cprqfb9nImhjlHmDeWXBa3NWe4VI88R3zyQCgoBv7U9jWNPViaFHIE=; _dd_s=rum=0&expire=1707360548972",
    "Referer": "https://www.yogiyo.co.kr/mobile/",
    "Sec-Ch-Ua": "\"Not A(Brand\";v=\"99\", \"Google Chrome\";v=\"121\", \"Chromium\";v=\"121\"",
    "Sec-Ch-Ua-Mobile": "?0",
    "Sec-Ch-Ua-Platform": "\"Windows\"",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36",
    "X-Apikey": "iphoneap",
    "X-Apisecret": "fe5183cc3dea12bd0ce299cf110a75a2"
}

# %%
response = requests.get(url, headers=headers, data=json.dumps(payload))
a = response.json()

# %%
response.text
# Out:
# '{"pagination":{"per_page":60,"current_page":2,"total_pages":32,"total_objects":1872},"restaurants":[{"id":1306678,"name":"모두의죽-강남점","except_cash":false,"categories":["테이크아웃","도시락죽","분식","프랜차이즈","1인분주문","한식","신규맛집"],"tags":[],"payment_methods":["creditcard","online"],"discount_percent":0,"restaurant_type":"food","additional_discount":0,"review_avg":4.8,"review_count":5,"is_open":true,"franchise_id":null,"lat":37.5005959,"lng":127.0427027,"owner_reply_count":4,"begin":"08:10:00","end":"22:50:00","new_rating":0.199491,"distance":1.49393,"is_new":true,"maximum_discount_coupon_price":4000,"has_shop_coupons":true,"serving_type":"vd","available_serving_types":["od","vd","pickup"],"min_order_amount":5900,"free_delivery_threshold":0,"is_deliverable":true,"reason":null,"surcharge":0,"adjusted_delivery_fee":1400,"estimated_delivery_time":"30~35분","is_ypx":true,"section":"contract","section_pos":94,"list_pos":121,"phone":"050720837300","address":"서울특별시 강남구 역삼동 721-4 이원빌딩 지하1층 6호","logo_url":"ht
# ...

# %%
review_url = "https://www.yogiyo.co.kr/api/v1/reviews/1190170/?count=100&only_photo_review=false&page=1&sort=time"

review_payload = {
    "count": 10,
    "only_photo_review": "false",
    "page": 2,
    "sort": "time",
}

review_headers = {
    "Accept": "application/json",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Authorization": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE3MDczNTY0MzgsImV4cCI6MTcwNzM2MzYzOCwicGxhdGZvcm0iOiJZR1kiLCJyb2xlIjoidXNlciIsInN1Yl9pZCI6Ijg0NDUzMjE5NyIsImJhc2VfdXJsIjoiaHR0cHM6Ly93d3cueW9naXlvLmNvLmtyIn0.n4yif8czFLhJbvEPe2HV6TxRFJmz0Vu68uSXBI3HlOOvtidTuC_hf1XQ_mUxXuM1SMlsEBxHGlqKVOOf5O6_aa4aBUsUggV7oN1dvFHU7bbpcpi837rlrGJIVNlG7kmHYHsftGsiUg_GjMI_lXvj7ygNE26cuBKT0NBgKuQaqNhDUVohOo9BMDyvcn_ojsQ39eN8GlcalwCIGySnIH_mZ3DPgzo-IYv8UAeLb4cqZR_894_KjaeUVDO5lQipszXfKVAhPEGZfOzgaDlt0Mem_As0sRKexgeYm4dEiyNSoxBNR9UukP4z7NPQR2bOVYUDFfChOUKxEZbWzkulevT_Lw",
    "Content-Type": "application/x-www-form-urlencoded",
    "Cookie": "optimizelyEndUserId=oeu1707217256129r0.4160384362789571; _gid=GA1.3.1286748026.1707217257; _fwb=235BZ2hbzqql3HOynLrZUjJ.1707217256848; _gcl_au=1.1.2062595015.1707217257; _fbp=fb.2.1707217257037.2107194958; _ga_6KMY7BWK8X=GS1.1.1707356497.5.0.1707356497.60.0.0; _ga=GA1.3.1795561733.1707217257; RestaurantListCookieTrigger=true; __cf_bm=JoCHAswANcbaQ2yqAAr2mV7evEuzd1dp6TVmfJX8oW0-1707359566-1-AcHvs5GbSJ0hL0k5+adaCOr0o6i17VC42cprqfb9nImhjlHmDeWXBa3NWe4VI88R3zyQCgoBv7U9jWNPViaFHIE=; RestaurantMenuCookieTrigger=true; wcs_bt=s_51119d387dfa:1707360467; _dd_s=rum=0&expire=1707361382481",
    "Referer": "https://www.yogiyo.co.kr/mobile/",
    "Sec-Ch-Ua": "\"Not A(Brand\";v=\"99\", \"Google Chrome\";v=\"121\", \"Chromium\";v=\"121\"",
    "Sec-Ch-Ua-Mobile": "?0",
    "Sec-Ch-Ua-Platform": "\"Windows\"",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36",
    "X-Apikey": "iphoneap",
    "X-Apisecret": "fe5183cc3dea12bd0ce299cf110a75a2"
}

# %%
response = requests.get(review_url, headers=review_headers, data=json.dumps(review_payload))
review = response.json()

# %%
len(review)
# Out:
# 100
