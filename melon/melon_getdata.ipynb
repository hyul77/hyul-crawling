# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
head = {"User-Agent":
"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0"}

# %%
melon_r = requests.get("https://www.melon.com/chart/index.htm",headers=head)

# %%
bs = BeautifulSoup(melon_r.text)
p = re.compile("[0-9]+")

# %%
for x in bs.findAll("div", class_ = "wrap_song_info")[::2]:
    print(x.find("a").text, end=", ")
    print(p.findall(x.find("a")['href'])[-1])
# Out:
# Perfect Night, 36910957
# To. X, 37003911
# 비의 랩소디, 37023625
# Drama, 36956630
# 첫 눈, 4352438
# 사랑은 늘 도망가, 34061322
# 헤어지자 말해요, 36382580
# 인사, 34451383
# Seven (feat. Latto) - Clean Ver., 36617841
# 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)), 36699489
# Baddie, 36871671
# 에피소드, 37053556
# Do or Die, 36855841
# 모래 알갱이, 36502910
# 우리들의 블루스, 34908740
# Love Lee, 36713849
# You & Me, 36852553
# I AM, 36356993
# 다시 만날 수 있을까, 35008524
# 이제 나만 믿어요, 32508053
# Love 119, 37098744
# Get A Guitar, 36717264
# 무지개, 35008525
# 후라이의 꿈, 36713850
# London Boy, 35834583
# Super Shy, 36599950
# 아버지, 35008527
# Polaroid, 35834584
# Standing Next to You, 36936167
# Ditto, 35945927
# 인생찬가, 35008534
# 너의 모든 순간, 4446485
# 사막에서 꽃을 피우듯, 36616378
# A bientot, 35008528
# 잘 지내자, 우리 (여름날 우리 X 로이킴), 36595401
# ETA, 36635522
# Hype Boy, 35454426
# 퀸카 (Queencard), 36430773
# 별 떨어진다 (I Do), 36778869
# 연애편지, 35008532
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지, 32061975
# Discord, 36877939
# 사랑인가 봐, 34657844
# Either Way, 36824901
# ...

# %%
bs.findAll("div", class_="wrap_song_info")[::2]
# Out:
# [<div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',36910957);" title="Perfect Night 재생">Perfect Night</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3092950');" title="LE SSERAFIM (르세라핌) - 페이지 이동">LE SSERAFIM (르세라핌)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3092950');" title="LE SSERAFIM (르세라핌) - 페이지 이동">LE SSERAFIM (르세라핌)</a></span>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',37003911);" title="To. X 재생">To. X</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
# ...

# %%
bs.findAll("div", class_="wrap_song_info")[2]
# Out:
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37003911);" title="To. X 재생">To. X</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('236797');" title="태연 (TAEYEON) - 페이지 이동">태연 (TAEYEON)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('236797');" title="태연 (TAEYEON) - 페이지 이동">태연 (TAEYEON)</a></span>
# </div>
# </div>
